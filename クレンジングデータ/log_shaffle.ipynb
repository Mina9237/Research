# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
#from sklearn.model_selection import train_test_split
import pandas as pd
import sys
import collections
import matplotlib.pyplot as plt
# data process
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
all_data= pd.read_excel("./20160809sakujo.xlsx")




#print(all_data.head())
#sys.exit()
#print(all_data_2.head())
#print(all_data.isnull().sum())
all_data_2 = all_data
#all_data_2 de,zyuuhukusurugyougaaru
#(all_data_2[all_data_2.duplicated()])

#sys.exit()
#print(all_data_2.isnull().sum())
#print(all_data_2.describe())
#sys.exit()
#print(len(all_data2))
time = []
time = all_data_2["Time"].unique()
kyoten = []
kyoten = all_data_2["name"].unique()

#band = []
list2 = []
list3 = []
list4 = []
pixel2 = []
CH2 = []
Cloud = []
terrian = []
CC = []
CS = []
for t in time:
    for n in kyoten:
        #band = all_data_2["band"][(all_data_2["Time"] == t) & (all_data_2["name"]== n)].values
        pixel2 = all_data_2["pixel"][(all_data_2["Time"] == t) & (all_data_2["name"] == n)].values
        CH2 = all_data_2["CH"][(all_data_2["Time"] == t) & (all_data_2["name"] == n)].values
        Cloud = all_data_2["cloud"][(all_data_2["Time"] == t) & (all_data_2["name"] == n)].values
        #terrian = all_data_2["terrian"][(all_data_2["Time"] == t) & (all_data_2["name"] == n)].values
        CC = all_data_2["cloudconfidence"][(all_data_2["Time"] == t) & (all_data_2["name"] == n)].values
        CS = all_data_2["cloudshade"][(all_data_2["Time"] == t) & (all_data_2["name"] == n)].values
        # print(CH1)
        if len(CH2) != 0:
            #list2 += [[n,t,pixel2, Cloud[0], terrian[0], CC[0], CS[0], CH2[0]]]
            list3 += [[pixel2, Cloud[0],CC[0], CS[0]]]
            list4 += [[CH2[0]]]

# print(list)

# array = np.array(list)
# rray
#array8 = np.array(list2)
#array8

""" 
with open("/home/meinai929/data_cleansed/mistake.txt","w") as f: 
    for i in range(0,1134): 
    #print(len(data_array[i][0])) 
        if len(array8[i][2]) != 11: 
            print(array8[i],file = f) 
 
"""
#ys.exit()
data_array = np.array(list3)
CH_array = np.array(list4)

#print(data_array.shape)
#print(CH_array.shape)
#sys.exit()
#data_array & CH_array numuber of rows are same (1134,1) (1134,5)
#print(data_array[0][0])
#print(len(data_array[0][0]))

#band no kazu ga, 10 to 22 no tokoro ga aru


#np.savetxt("/home/meinai929/data_cleansed/data_array_1205.txt",data_array,fmt = "%s")

#sys.exit()
def flatten(l):
    for el in l:
        if isinstance(el, collections.Iterable) and not isinstance(el, (str, bytes)):
            yield from flatten(el)
        else:
            yield el

list1 =[]
for x in data_array:
    list1 += flatten(x)

#print(len(list1))
#26415 1761*15= 26415ninaruhazu
#sys.exit()

def split_list(l, n):
    """ 
    リストをサブリストに分割する 
    :param l: リスト 
    :param n: サブリストの要素数 
    :return: 
    """
    for idx in range(0, len(l), n):
        yield l[idx:idx + n]

#print(list(split_list(list1, 14)))
inputs = np.array(list(split_list(list1, 14)))


scaler = preprocessing.MinMaxScaler()
#sc = StandardScaler()
#inputs_seikika = scaler.fit_transform(inputs)
#nputs_seikika_pixel = scaler.fit_transform(inputs[:,0:11])
#nputs_seikika_cloud = scaler.fit_transform(inputs[:,11:])
pixel_log = scaler.fit_transform(np.log(inputs[:,0:11]))
cloud = scaler.fit_transform(inputs[:,11:])
#print(inputs_seikika_pixel)
#print(inputs_seikika_cloud)

#nputs_seikika = np.concatenate((inputs_seikika_pixel,inputs_seikika_cloud),axis = 1)

input_log = np.concatenate((pixel_log,cloud),axis=1)
#print(input_log)

# %%
from sklearn.model_selection import train_test_split
#CH_seikika = scaler.fit_transform(CH_array)
CH_log = scaler.fit_transform(np.log(CH_array))

input_CH_log = np.concatenate((input_log,CH_log),axis=1)


#print(CH_seikika)
#sys.exit()
#plt.plot(inputs_seikika,CH_array)
#plt.show()
#print(CH_seikika)
#sys.exit()

#print(inputs_seikika)

#sys.exit()
zenbu_train,zenbu_test = train_test_split(input_CH_log,shuffle=True)
#inputs_train, inputs_test = train_test_split(input_log, shuffle=False)
#CH_train, CH_test = train_test_split(CH_log, shuffle=False)

#print(zenbu_train.shape)



#print(inputs_train.shape)
#sys.exit()
#print(inputs_train[0])
#print(CH_train.shape)
#print(inputs_train.shape)
#print(inputs.shape)
#print(CH_train.shape)
#sys.exit()
#print(inputs_train,CH_train)
#print(inputs_train.shape)
#print(inputs_train)

#sys.exit()
#input 15 * 1134
#model kouchiku
inputs = keras.Input(shape =(14,) )

dense = layers.Dense(64,activation ="tanh")
x = dense(inputs)

x = layers.Dense(64,activation="tanh")(x)

outputs = layers.Dense(1)(x)

model = keras.Model(inputs=inputs,outputs=outputs,name="test1")

model.compile(
    loss="mean_squared_error",
    optimizer="sgd",
    #metrics=["accuracy"],
    metrics=[tf.keras.metrics.MeanAbsolutePercentageError(
    name="mean_absolute_percentage_error", dtype=None
)]
)

history = model.fit(zenbu_train[:,0:14], zenbu_train[:,14:], batch_size=100, epochs=100, validation_split=0.2)

test_scores = model.evaluate(zenbu_test[:,0:14], zenbu_test[:,14:], verbose=2)
print("Test loss:", test_scores[0])
print("MAPE:", test_scores[1])
# Out:
# Train on 1004 samples, validate on 251 samples
# Epoch 1/100
# 1004/1004 [==============================] - 0s 443us/sample - loss: 0.1027 - mean_absolute_percentage_error: 416944.8438 - val_loss: 0.0286 - val_mean_absolute_percentage_error: 38.7295
# Epoch 2/100
# 1004/1004 [==============================] - 0s 28us/sample - loss: 0.0291 - mean_absolute_percentage_error: 427935.9375 - val_loss: 0.0277 - val_mean_absolute_percentage_error: 40.2930
# Epoch 3/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0288 - mean_absolute_percentage_error: 413525.8438 - val_loss: 0.0276 - val_mean_absolute_percentage_error: 38.7324
# Epoch 4/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0284 - mean_absolute_percentage_error: 419269.0625 - val_loss: 0.0271 - val_mean_absolute_percentage_error: 39.0267
# Epoch 5/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0282 - mean_absolute_percentage_error: 421186.8438 - val_loss: 0.0269 - val_mean_absolute_percentage_error: 38.5409
# Epoch 6/100
# 1004/1004 [==============================] - 0s 35us/sample - loss: 0.0280 - mean_absolute_percentage_error: 430869.2500 - val_loss: 0.0266 - val_mean_absolute_percentage_error: 38.4033
# Epoch 7/100
# 1004/1004 [==============================] - 0s 35us/sample - loss: 0.0277 - mean_absolute_percentage_error: 426244.5000 - val_loss: 0.0298 - val_mean_absolute_percentage_error: 36.0189
# Epoch 8/100
# 1004/1004 [==============================] - 0s 32us/sample - loss: 0.0278 - mean_absolute_percentage_error: 388587.8438 - val_loss: 0.0302 - val_mean_absolute_percentage_error: 36.0039
# Epoch 9/100
# 1004/1004 [==============================] - 0s 35us/sample - loss: 0.0278 - mean_absolute_percentage_error: 414053.0000 - val_loss: 0.0273 - val_mean_absolute_percentage_error: 36.1141
# Epoch 10/100
# 1004/1004 [==============================] - 0s 30us/sample - loss: 0.0271 - mean_absolute_percentage_error: 416764.1562 - val_loss: 0.0268 - val_mean_absolute_percentage_error: 41.4362
# Epoch 11/100
# 1004/1004 [==============================] - 0s 32us/sample - loss: 0.0275 - mean_absolute_percentage_error: 448881.1875 - val_loss: 0.0257 - val_mean_absolute_percentage_error: 38.6402
# Epoch 12/100
# 1004/1004 [==============================] - 0s 30us/sample - loss: 0.0269 - mean_absolute_percentage_error: 442722.1562 - val_loss: 0.0289 - val_mean_absolute_percentage_error: 35.0040
# Epoch 13/100
# 1004/1004 [==============================] - 0s 36us/sample - loss: 0.0270 - mean_absolute_percentage_error: 411738.6250 - val_loss: 0.0256 - val_mean_absolute_percentage_error: 36.8471
# Epoch 14/100
# 1004/1004 [==============================] - 0s 32us/sample - loss: 0.0263 - mean_absolute_percentage_error: 411304.0938 - val_loss: 0.0252 - val_mean_absolute_percentage_error: 39.2236
# Epoch 15/100
# 1004/1004 [==============================] - 0s 31us/sample - loss: 0.0263 - mean_absolute_percentage_error: 416757.3750 - val_loss: 0.0268 - val_mean_absolute_percentage_error: 34.9294
# Epoch 16/100
# 1004/1004 [==============================] - 0s 31us/sample - loss: 0.0263 - mean_absolute_percentage_error: 414468.2812 - val_loss: 0.0249 - val_mean_absolute_percentage_error: 37.4518
# Epoch 17/100
# 1004/1004 [==============================] - 0s 34us/sample - loss: 0.0261 - mean_absolute_percentage_error: 437886.0312 - val_loss: 0.0298 - val_mean_absolute_percentage_error: 34.6095
# Epoch 18/100
# 1004/1004 [==============================] - 0s 36us/sample - loss: 0.0264 - mean_absolute_percentage_error: 379633.2812 - val_loss: 0.0250 - val_mean_absolute_percentage_error: 36.2194
# Epoch 19/100
# 1004/1004 [==============================] - 0s 30us/sample - loss: 0.0258 - mean_absolute_percentage_error: 423017.5000 - val_loss: 0.0262 - val_mean_absolute_percentage_error: 34.8338
# Epoch 20/100
# 1004/1004 [==============================] - 0s 30us/sample - loss: 0.0258 - mean_absolute_percentage_error: 392454.0000 - val_loss: 0.0249 - val_mean_absolute_percentage_error: 39.7928
# Epoch 21/100
# 1004/1004 [==============================] - 0s 34us/sample - loss: 0.0259 - mean_absolute_percentage_error: 414481.6250 - val_loss: 0.0247 - val_mean_absolute_percentage_error: 36.3089
# Epoch 22/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0256 - mean_absolute_percentage_error: 409371.4062 - val_loss: 0.0268 - val_mean_absolute_percentage_error: 34.2675
# Epoch 23/100
# 1004/1004 [==============================] - 0s 26us/sample - loss: 0.0257 - mean_absolute_percentage_error: 362591.6250 - val_loss: 0.0244 - val_mean_absolute_percentage_error: 36.7753
# Epoch 24/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0254 - mean_absolute_percentage_error: 395937.7188 - val_loss: 0.0271 - val_mean_absolute_percentage_error: 34.2280
# Epoch 25/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0256 - mean_absolute_percentage_error: 406448.3125 - val_loss: 0.0253 - val_mean_absolute_percentage_error: 34.7502
# Epoch 26/100
# 1004/1004 [==============================] - 0s 36us/sample - loss: 0.0253 - mean_absolute_percentage_error: 402055.9062 - val_loss: 0.0262 - val_mean_absolute_percentage_error: 34.0291
# Epoch 27/100
# 1004/1004 [==============================] - 0s 35us/sample - loss: 0.0254 - mean_absolute_percentage_error: 404921.0938 - val_loss: 0.0262 - val_mean_absolute_percentage_error: 33.7568
# Epoch 28/100
# 1004/1004 [==============================] - 0s 40us/sample - loss: 0.0254 - mean_absolute_percentage_error: 401594.2812 - val_loss: 0.0247 - val_mean_absolute_percentage_error: 34.9685
# Epoch 29/100
# 1004/1004 [==============================] - 0s 32us/sample - loss: 0.0252 - mean_absolute_percentage_error: 393911.8750 - val_loss: 0.0265 - val_mean_absolute_percentage_error: 33.7936
# Epoch 30/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0254 - mean_absolute_percentage_error: 385495.0312 - val_loss: 0.0254 - val_mean_absolute_percentage_error: 34.4145
# Epoch 31/100
# 1004/1004 [==============================] - 0s 34us/sample - loss: 0.0252 - mean_absolute_percentage_error: 395061.4062 - val_loss: 0.0257 - val_mean_absolute_percentage_error: 34.1731
# Epoch 32/100
# 1004/1004 [==============================] - 0s 27us/sample - loss: 0.0252 - mean_absolute_percentage_error: 400811.5625 - val_loss: 0.0246 - val_mean_absolute_percentage_error: 34.9626
# Epoch 33/100
# 1004/1004 [==============================] - 0s 26us/sample - loss: 0.0251 - mean_absolute_percentage_error: 400936.0938 - val_loss: 0.0251 - val_mean_absolute_percentage_error: 34.5751
# Epoch 34/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0251 - mean_absolute_percentage_error: 405275.3438 - val_loss: 0.0256 - val_mean_absolute_percentage_error: 34.6015
# Epoch 35/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0251 - mean_absolute_percentage_error: 394646.5625 - val_loss: 0.0240 - val_mean_absolute_percentage_error: 38.9957
# Epoch 36/100
# 1004/1004 [==============================] - 0s 30us/sample - loss: 0.0252 - mean_absolute_percentage_error: 399311.5625 - val_loss: 0.0244 - val_mean_absolute_percentage_error: 34.7428
# Epoch 37/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0250 - mean_absolute_percentage_error: 401234.7812 - val_loss: 0.0240 - val_mean_absolute_percentage_error: 35.2768
# Epoch 38/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0249 - mean_absolute_percentage_error: 416086.6875 - val_loss: 0.0254 - val_mean_absolute_percentage_error: 33.6531
# Epoch 39/100
# 1004/1004 [==============================] - 0s 30us/sample - loss: 0.0250 - mean_absolute_percentage_error: 394955.8750 - val_loss: 0.0263 - val_mean_absolute_percentage_error: 33.4862
# Epoch 40/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0250 - mean_absolute_percentage_error: 352367.5000 - val_loss: 0.0266 - val_mean_absolute_percentage_error: 33.3826
# Epoch 41/100
# 1004/1004 [==============================] - 0s 27us/sample - loss: 0.0250 - mean_absolute_percentage_error: 396511.2188 - val_loss: 0.0254 - val_mean_absolute_percentage_error: 42.1642
# Epoch 42/100
# 1004/1004 [==============================] - 0s 27us/sample - loss: 0.0256 - mean_absolute_percentage_error: 475328.4062 - val_loss: 0.0236 - val_mean_absolute_percentage_error: 36.3355
# Epoch 43/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0247 - mean_absolute_percentage_error: 393395.4688 - val_loss: 0.0236 - val_mean_absolute_percentage_error: 36.1085
# Epoch 44/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0248 - mean_absolute_percentage_error: 399939.0625 - val_loss: 0.0237 - val_mean_absolute_percentage_error: 38.4733
# Epoch 45/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0247 - mean_absolute_percentage_error: 422356.2812 - val_loss: 0.0237 - val_mean_absolute_percentage_error: 35.8110
# Epoch 46/100
# 1004/1004 [==============================] - 0s 32us/sample - loss: 0.0247 - mean_absolute_percentage_error: 380708.9375 - val_loss: 0.0236 - val_mean_absolute_percentage_error: 37.6322
# Epoch 47/100
# 1004/1004 [==============================] - 0s 31us/sample - loss: 0.0249 - mean_absolute_percentage_error: 418075.8750 - val_loss: 0.0262 - val_mean_absolute_percentage_error: 33.2659
# Epoch 48/100
# 1004/1004 [==============================] - 0s 30us/sample - loss: 0.0249 - mean_absolute_percentage_error: 390816.2500 - val_loss: 0.0236 - val_mean_absolute_percentage_error: 35.7047
# Epoch 49/100
# 1004/1004 [==============================] - 0s 34us/sample - loss: 0.0247 - mean_absolute_percentage_error: 397188.9062 - val_loss: 0.0235 - val_mean_absolute_percentage_error: 36.2274
# Epoch 50/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0246 - mean_absolute_percentage_error: 404978.5938 - val_loss: 0.0239 - val_mean_absolute_percentage_error: 35.2632
# Epoch 51/100
# 1004/1004 [==============================] - 0s 30us/sample - loss: 0.0246 - mean_absolute_percentage_error: 373501.2500 - val_loss: 0.0241 - val_mean_absolute_percentage_error: 34.6180
# Epoch 52/100
# 1004/1004 [==============================] - 0s 31us/sample - loss: 0.0247 - mean_absolute_percentage_error: 391857.9375 - val_loss: 0.0275 - val_mean_absolute_percentage_error: 33.0152
# Epoch 53/100
# 1004/1004 [==============================] - 0s 30us/sample - loss: 0.0250 - mean_absolute_percentage_error: 376402.0312 - val_loss: 0.0238 - val_mean_absolute_percentage_error: 34.9415
# Epoch 54/100
# 1004/1004 [==============================] - 0s 32us/sample - loss: 0.0246 - mean_absolute_percentage_error: 409550.9688 - val_loss: 0.0234 - val_mean_absolute_percentage_error: 35.8608
# Epoch 55/100
# 1004/1004 [==============================] - 0s 32us/sample - loss: 0.0246 - mean_absolute_percentage_error: 406957.7188 - val_loss: 0.0236 - val_mean_absolute_percentage_error: 35.1377
# Epoch 56/100
# 1004/1004 [==============================] - 0s 31us/sample - loss: 0.0245 - mean_absolute_percentage_error: 386435.9688 - val_loss: 0.0243 - val_mean_absolute_percentage_error: 34.0696
# Epoch 57/100
# 1004/1004 [==============================] - 0s 39us/sample - loss: 0.0245 - mean_absolute_percentage_error: 392623.0000 - val_loss: 0.0256 - val_mean_absolute_percentage_error: 33.2436
# Epoch 58/100
# 1004/1004 [==============================] - 0s 28us/sample - loss: 0.0247 - mean_absolute_percentage_error: 367390.4688 - val_loss: 0.0234 - val_mean_absolute_percentage_error: 37.7999
# Epoch 59/100
# 1004/1004 [==============================] - 0s 32us/sample - loss: 0.0247 - mean_absolute_percentage_error: 408870.2500 - val_loss: 0.0238 - val_mean_absolute_percentage_error: 34.7186
# Epoch 60/100
# 1004/1004 [==============================] - 0s 28us/sample - loss: 0.0245 - mean_absolute_percentage_error: 386091.3125 - val_loss: 0.0233 - val_mean_absolute_percentage_error: 36.0252
# Epoch 61/100
# 1004/1004 [==============================] - 0s 32us/sample - loss: 0.0244 - mean_absolute_percentage_error: 413774.4375 - val_loss: 0.0241 - val_mean_absolute_percentage_error: 34.2189
# Epoch 62/100
# 1004/1004 [==============================] - 0s 26us/sample - loss: 0.0244 - mean_absolute_percentage_error: 406170.6250 - val_loss: 0.0264 - val_mean_absolute_percentage_error: 33.2949
# Epoch 63/100
# 1004/1004 [==============================] - 0s 32us/sample - loss: 0.0247 - mean_absolute_percentage_error: 363768.3125 - val_loss: 0.0248 - val_mean_absolute_percentage_error: 33.5129
# Epoch 64/100
# 1004/1004 [==============================] - 0s 28us/sample - loss: 0.0246 - mean_absolute_percentage_error: 384744.7188 - val_loss: 0.0233 - val_mean_absolute_percentage_error: 36.8015
# Epoch 65/100
# 1004/1004 [==============================] - 0s 31us/sample - loss: 0.0245 - mean_absolute_percentage_error: 400111.5625 - val_loss: 0.0242 - val_mean_absolute_percentage_error: 34.3836
# Epoch 66/100
# 1004/1004 [==============================] - 0s 27us/sample - loss: 0.0244 - mean_absolute_percentage_error: 381554.6875 - val_loss: 0.0264 - val_mean_absolute_percentage_error: 33.2875
# Epoch 67/100
# 1004/1004 [==============================] - 0s 32us/sample - loss: 0.0247 - mean_absolute_percentage_error: 372803.8125 - val_loss: 0.0234 - val_mean_absolute_percentage_error: 35.6900
# Epoch 68/100
# 1004/1004 [==============================] - 0s 26us/sample - loss: 0.0244 - mean_absolute_percentage_error: 386331.5000 - val_loss: 0.0236 - val_mean_absolute_percentage_error: 35.3393
# Epoch 69/100
# 1004/1004 [==============================] - 0s 31us/sample - loss: 0.0244 - mean_absolute_percentage_error: 372862.6875 - val_loss: 0.0233 - val_mean_absolute_percentage_error: 37.5714
# Epoch 70/100
# 1004/1004 [==============================] - 0s 27us/sample - loss: 0.0244 - mean_absolute_percentage_error: 407415.6875 - val_loss: 0.0273 - val_mean_absolute_percentage_error: 33.2577
# Epoch 71/100
# 1004/1004 [==============================] - 0s 34us/sample - loss: 0.0247 - mean_absolute_percentage_error: 374898.5938 - val_loss: 0.0237 - val_mean_absolute_percentage_error: 34.8676
# Epoch 72/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0244 - mean_absolute_percentage_error: 373878.9375 - val_loss: 0.0244 - val_mean_absolute_percentage_error: 34.1711
# Epoch 73/100
# 1004/1004 [==============================] - 0s 30us/sample - loss: 0.0244 - mean_absolute_percentage_error: 378362.6562 - val_loss: 0.0238 - val_mean_absolute_percentage_error: 34.4054
# Epoch 74/100
# 1004/1004 [==============================] - 0s 26us/sample - loss: 0.0243 - mean_absolute_percentage_error: 391524.3125 - val_loss: 0.0232 - val_mean_absolute_percentage_error: 36.4555
# Epoch 75/100
# 1004/1004 [==============================] - 0s 28us/sample - loss: 0.0244 - mean_absolute_percentage_error: 390658.5625 - val_loss: 0.0243 - val_mean_absolute_percentage_error: 34.1565
# Epoch 76/100
# 1004/1004 [==============================] - 0s 30us/sample - loss: 0.0243 - mean_absolute_percentage_error: 379755.5938 - val_loss: 0.0233 - val_mean_absolute_percentage_error: 36.4094
# Epoch 77/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0243 - mean_absolute_percentage_error: 380222.0312 - val_loss: 0.0236 - val_mean_absolute_percentage_error: 34.7615
# Epoch 78/100
# 1004/1004 [==============================] - 0s 31us/sample - loss: 0.0243 - mean_absolute_percentage_error: 378194.8438 - val_loss: 0.0232 - val_mean_absolute_percentage_error: 36.9783
# Epoch 79/100
# 1004/1004 [==============================] - 0s 28us/sample - loss: 0.0245 - mean_absolute_percentage_error: 382090.0938 - val_loss: 0.0254 - val_mean_absolute_percentage_error: 33.4773
# Epoch 80/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0244 - mean_absolute_percentage_error: 381553.0000 - val_loss: 0.0242 - val_mean_absolute_percentage_error: 40.1299
# Epoch 81/100
# 1004/1004 [==============================] - 0s 28us/sample - loss: 0.0247 - mean_absolute_percentage_error: 414156.2500 - val_loss: 0.0243 - val_mean_absolute_percentage_error: 34.8621
# Epoch 82/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0243 - mean_absolute_percentage_error: 369612.4062 - val_loss: 0.0241 - val_mean_absolute_percentage_error: 34.1914
# Epoch 83/100
# 1004/1004 [==============================] - 0s 27us/sample - loss: 0.0242 - mean_absolute_percentage_error: 364959.4688 - val_loss: 0.0233 - val_mean_absolute_percentage_error: 35.3219
# Epoch 84/100
# 1004/1004 [==============================] - 0s 27us/sample - loss: 0.0244 - mean_absolute_percentage_error: 395350.5000 - val_loss: 0.0252 - val_mean_absolute_percentage_error: 33.4166
# Epoch 85/100
# 1004/1004 [==============================] - 0s 28us/sample - loss: 0.0243 - mean_absolute_percentage_error: 363781.6875 - val_loss: 0.0235 - val_mean_absolute_percentage_error: 35.2110
# Epoch 86/100
# 1004/1004 [==============================] - 0s 27us/sample - loss: 0.0243 - mean_absolute_percentage_error: 361345.6875 - val_loss: 0.0246 - val_mean_absolute_percentage_error: 33.7097
# Epoch 87/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0243 - mean_absolute_percentage_error: 378535.8750 - val_loss: 0.0262 - val_mean_absolute_percentage_error: 33.1593
# Epoch 88/100
# 1004/1004 [==============================] - 0s 27us/sample - loss: 0.0244 - mean_absolute_percentage_error: 381991.7812 - val_loss: 0.0255 - val_mean_absolute_percentage_error: 33.2691
# Epoch 89/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0244 - mean_absolute_percentage_error: 370633.5000 - val_loss: 0.0234 - val_mean_absolute_percentage_error: 35.0809
# Epoch 90/100
# 1004/1004 [==============================] - 0s 30us/sample - loss: 0.0242 - mean_absolute_percentage_error: 384546.1875 - val_loss: 0.0258 - val_mean_absolute_percentage_error: 33.2939
# Epoch 91/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0244 - mean_absolute_percentage_error: 387979.1875 - val_loss: 0.0233 - val_mean_absolute_percentage_error: 36.0740
# Epoch 92/100
# 1004/1004 [==============================] - 0s 27us/sample - loss: 0.0242 - mean_absolute_percentage_error: 377954.4375 - val_loss: 0.0232 - val_mean_absolute_percentage_error: 35.8713
# Epoch 93/100
# 1004/1004 [==============================] - 0s 30us/sample - loss: 0.0242 - mean_absolute_percentage_error: 387906.9688 - val_loss: 0.0244 - val_mean_absolute_percentage_error: 34.0561
# Epoch 94/100
# 1004/1004 [==============================] - 0s 27us/sample - loss: 0.0242 - mean_absolute_percentage_error: 381166.0312 - val_loss: 0.0232 - val_mean_absolute_percentage_error: 36.4171
# Epoch 95/100
# 1004/1004 [==============================] - 0s 28us/sample - loss: 0.0242 - mean_absolute_percentage_error: 381197.8125 - val_loss: 0.0233 - val_mean_absolute_percentage_error: 35.5791
# Epoch 96/100
# 1004/1004 [==============================] - 0s 31us/sample - loss: 0.0242 - mean_absolute_percentage_error: 383215.5312 - val_loss: 0.0242 - val_mean_absolute_percentage_error: 34.4714
# Epoch 97/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0243 - mean_absolute_percentage_error: 358800.9375 - val_loss: 0.0236 - val_mean_absolute_percentage_error: 39.3741
# Epoch 98/100
# 1004/1004 [==============================] - 0s 30us/sample - loss: 0.0245 - mean_absolute_percentage_error: 388711.5938 - val_loss: 0.0239 - val_mean_absolute_percentage_error: 34.3064
# Epoch 99/100
# 1004/1004 [==============================] - 0s 26us/sample - loss: 0.0241 - mean_absolute_percentage_error: 371381.5000 - val_loss: 0.0232 - val_mean_absolute_percentage_error: 36.0862
# Epoch 100/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0242 - mean_absolute_percentage_error: 391006.9062 - val_loss: 0.0249 - val_mean_absolute_percentage_error: 33.8530
# 419/419 - 0s - loss: 0.0197 - mean_absolute_percentage_error: 34.2105
# Test loss: 0.019680870105656917
# MAPE: 34.21046
