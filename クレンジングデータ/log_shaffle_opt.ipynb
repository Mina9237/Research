# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
#from sklearn.model_selection import train_test_split
import pandas as pd
import sys
import collections
import matplotlib.pyplot as plt
# data process
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import optimizers

all_data= pd.read_excel("./all_data4_north.xlsx")




#print(all_data.head())
#sys.exit()
#print(all_data_2.head())
#print(all_data.isnull().sum())
all_data_2 = all_data
#all_data_2 de,zyuuhukusurugyougaaru
#(all_data_2[all_data_2.duplicated()])

#sys.exit()
#print(all_data_2.isnull().sum())
#print(all_data_2.describe())
#sys.exit()
#print(len(all_data2))
time = []
time = all_data_2["Time"].unique()
kyoten = []
kyoten = all_data_2["name"].unique()

#band = []
list2 = []
list3 = []
list4 = []
pixel2 = []
CH2 = []
Cloud = []
terrian = []
CC = []
CS = []
for t in time:
    for n in kyoten:
        #band = all_data_2["band"][(all_data_2["Time"] == t) & (all_data_2["name"]== n)].values
        pixel2 = all_data_2["pixel"][(all_data_2["Time"] == t) & (all_data_2["name"] == n)].values
        CH2 = all_data_2["CH"][(all_data_2["Time"] == t) & (all_data_2["name"] == n)].values
        Cloud = all_data_2["cloud"][(all_data_2["Time"] == t) & (all_data_2["name"] == n)].values
        #terrian = all_data_2["terrian"][(all_data_2["Time"] == t) & (all_data_2["name"] == n)].values
        CC = all_data_2["cloudconfidence"][(all_data_2["Time"] == t) & (all_data_2["name"] == n)].values
        CS = all_data_2["cloudshade"][(all_data_2["Time"] == t) & (all_data_2["name"] == n)].values
        # print(CH1)
        if len(CH2) != 0:
            #list2 += [[n,t,pixel2, Cloud[0], terrian[0], CC[0], CS[0], CH2[0]]]
            list3 += [[pixel2, Cloud[0],CC[0], CS[0]]]
            list4 += [[CH2[0]]]

# print(list)

# array = np.array(list)
# rray
#array8 = np.array(list2)
#array8

""" 
with open("/home/meinai929/data_cleansed/mistake.txt","w") as f: 
    for i in range(0,1134): 
    #print(len(data_array[i][0])) 
        if len(array8[i][2]) != 11: 
            print(array8[i],file = f) 
 
"""
#ys.exit()
data_array = np.array(list3)
CH_array = np.array(list4)

#print(data_array.shape)
#print(CH_array.shape)
#sys.exit()
#data_array & CH_array numuber of rows are same (1134,1) (1134,5)
#print(data_array[0][0])
#print(len(data_array[0][0]))

#band no kazu ga, 10 to 22 no tokoro ga aru


#np.savetxt("/home/meinai929/data_cleansed/data_array_1205.txt",data_array,fmt = "%s")

#sys.exit()
def flatten(l):
    for el in l:
        if isinstance(el, collections.Iterable) and not isinstance(el, (str, bytes)):
            yield from flatten(el)
        else:
            yield el

list1 =[]
for x in data_array:
    list1 += flatten(x)

#print(len(list1))
#26415 1761*15= 26415ninaruhazu
#sys.exit()

def split_list(l, n):
    """ 
    リストをサブリストに分割する 
    :param l: リスト 
    :param n: サブリストの要素数 
    :return: 
    """
    for idx in range(0, len(l), n):
        yield l[idx:idx + n]

#print(list(split_list(list1, 14)))
inputs = np.array(list(split_list(list1, 14)))


scaler = preprocessing.MinMaxScaler()
#sc = StandardScaler()
#inputs_seikika = scaler.fit_transform(inputs)
#nputs_seikika_pixel = scaler.fit_transform(inputs[:,0:11])
#nputs_seikika_cloud = scaler.fit_transform(inputs[:,11:])
pixel_log = scaler.fit_transform(np.log(inputs[:,0:11]))
cloud = scaler.fit_transform(inputs[:,11:])
#print(inputs_seikika_pixel)
#print(inputs_seikika_cloud)

#nputs_seikika = np.concatenate((inputs_seikika_pixel,inputs_seikika_cloud),axis = 1)

input_log = np.concatenate((pixel_log,cloud),axis=1)
#print(input_log)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      63   try:
# ---> 64     from tensorflow.python._pywrap_tensorflow_internal import *
#      65   # This try catch logic is because there is no bazel equivalent for py_extension.
#
# ImportError: DLL load failed: 指定されたモジュールが見つかりません。
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-2c3935d181fb> in <module>
#       1 import numpy as np
# ----> 2 import tensorflow as tf
#       3 from tensorflow import keras
#       4 from tensorflow.keras import layers
#       5 #from sklearn.model_selection import train_test_split
#
# ~\Anaconda3\lib\site-packages\tensorflow\__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\__init__.py in <module>
#      38 # pylint: disable=wildcard-import,g-bad-import-order,g-import-not-at-top
#      39
# ---> 40 from tensorflow.python.eager import context
#      41
#      42 # pylint: enable=wildcard-import
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\context.py in <module>
#      33 from tensorflow.core.protobuf import config_pb2
#      34 from tensorflow.core.protobuf import rewriter_config_pb2
# ---> 35 from tensorflow.python import pywrap_tfe
#      36 from tensorflow.python import tf2
#      37 from tensorflow.python.client import pywrap_tf_session
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\pywrap_tfe.py in <module>
#      26
#      27 # pylint: disable=invalid-import-order,g-bad-import-order, wildcard-import, unused-import
# ---> 28 from tensorflow.python import pywrap_tensorflow
#      29 from tensorflow.python._pywrap_tfe import *
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      81 for some common reasons and solutions.  Include the entire stack trace
#      82 above this error message when asking for help.""" % traceback.format_exc()
# ---> 83   raise ImportError(msg)
#      84
#      85 # pylint: enable=wildcard-import,g-import-not-at-top,unused-import,line-too-long
#
# ImportError: Traceback (most recent call last):
#   File "C:\Users\meina\Anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py", line 64, in <module>
#     from tensorflow.python._pywrap_tensorflow_internal import *
# ImportError: DLL load failed: 指定されたモジュールが見つかりません。
#
#
# Failed to load the native TensorFlow runtime.
#
# See https://www.tensorflow.org/install/errors
#
# for some common reasons and solutions.  Include the entire stack trace
# above this error message when asking for help.

# %%
from sklearn.model_selection import train_test_split
#CH_seikika = scaler.fit_transform(CH_array)
CH_log = scaler.fit_transform(np.log(CH_array))

input_CH_log = np.concatenate((input_log,CH_log),axis=1)


#print(CH_seikika)
#sys.exit()
#plt.plot(inputs_seikika,CH_array)
#plt.show()
#print(CH_seikika)
#sys.exit()

#print(inputs_seikika)

#sys.exit()
zenbu_train,zenbu_test = train_test_split(input_CH_log,shuffle=True)
#inputs_train, inputs_test = train_test_split(input_log, shuffle=False)
#CH_train, CH_test = train_test_split(CH_log, shuffle=False)

#print(zenbu_train.shape)



#print(inputs_train.shape)
#sys.exit()
#print(inputs_train[0])
#print(CH_train.shape)
#print(inputs_train.shape)
#print(inputs.shape)
#print(CH_train.shape)
#sys.exit()
#print(inputs_train,CH_train)
#print(inputs_train.shape)
#print(inputs_train)

#sys.exit()
#input 15 * 1134
#model kouchiku
inputs = keras.Input(shape =(14,) )

dense = layers.Dense(64,activation ="relu")
x = dense(inputs)

x = layers.Dense(64,activation="relu")(x)

outputs = layers.Dense(1)(x)

model = keras.Model(inputs=inputs,outputs=outputs,name="test1")

model.compile(
    #keras.optimizers.SGD(lr=0.01, momentum=0.0, decay=0.0, nesterov=False),
    loss="mean_squared_error",
    optimizer="adam",
    #metrics=["accuracy"],
    metrics=[tf.keras.metrics.MeanAbsolutePercentageError(
    name="mean_absolute_percentage_error", dtype=None
)]
)

history = model.fit(zenbu_train[:,0:14], zenbu_train[:,14:], batch_size=10, epochs=100, validation_split=0.2)

test_scores = model.evaluate(zenbu_test[:,0:14], zenbu_test[:,14:], verbose=2)
print("Test loss:", test_scores[0])
print("MAPE:", test_scores[1])
# Out:
# Train on 1004 samples, validate on 251 samples
# Epoch 1/100
# 1004/1004 [==============================] - 1s 558us/sample - loss: 0.0347 - mean_absolute_percentage_error: 386419.6250 - val_loss: 0.0238 - val_mean_absolute_percentage_error: 37.3577
# Epoch 2/100
# 1004/1004 [==============================] - 0s 152us/sample - loss: 0.0234 - mean_absolute_percentage_error: 384795.6562 - val_loss: 0.0235 - val_mean_absolute_percentage_error: 36.9108
# Epoch 3/100
# 1004/1004 [==============================] - 0s 154us/sample - loss: 0.0232 - mean_absolute_percentage_error: 374138.1875 - val_loss: 0.0243 - val_mean_absolute_percentage_error: 37.4422
# Epoch 4/100
# 1004/1004 [==============================] - 0s 141us/sample - loss: 0.0226 - mean_absolute_percentage_error: 374267.5938 - val_loss: 0.0235 - val_mean_absolute_percentage_error: 40.1323
# Epoch 5/100
# 1004/1004 [==============================] - 0s 151us/sample - loss: 0.0225 - mean_absolute_percentage_error: 396351.3438 - val_loss: 0.0238 - val_mean_absolute_percentage_error: 35.5925
# Epoch 6/100
# 1004/1004 [==============================] - 0s 158us/sample - loss: 0.0224 - mean_absolute_percentage_error: 311480.6875 - val_loss: 0.0271 - val_mean_absolute_percentage_error: 35.0436
# Epoch 7/100
# 1004/1004 [==============================] - 0s 160us/sample - loss: 0.0226 - mean_absolute_percentage_error: 392531.8125 - val_loss: 0.0236 - val_mean_absolute_percentage_error: 35.3309
# Epoch 8/100
# 1004/1004 [==============================] - 0s 156us/sample - loss: 0.0220 - mean_absolute_percentage_error: 429966.3750 - val_loss: 0.0240 - val_mean_absolute_percentage_error: 35.1480
# Epoch 9/100
# 1004/1004 [==============================] - 0s 174us/sample - loss: 0.0217 - mean_absolute_percentage_error: 326821.6562 - val_loss: 0.0228 - val_mean_absolute_percentage_error: 37.6736
# Epoch 10/100
# 1004/1004 [==============================] - 0s 159us/sample - loss: 0.0225 - mean_absolute_percentage_error: 352840.0000 - val_loss: 0.0231 - val_mean_absolute_percentage_error: 39.1605
# Epoch 11/100
# 1004/1004 [==============================] - 0s 169us/sample - loss: 0.0217 - mean_absolute_percentage_error: 385905.8125 - val_loss: 0.0228 - val_mean_absolute_percentage_error: 39.1744
# Epoch 12/100
# 1004/1004 [==============================] - 0s 160us/sample - loss: 0.0221 - mean_absolute_percentage_error: 354173.0938 - val_loss: 0.0231 - val_mean_absolute_percentage_error: 36.6343
# Epoch 13/100
# 1004/1004 [==============================] - 0s 181us/sample - loss: 0.0213 - mean_absolute_percentage_error: 355740.8438 - val_loss: 0.0228 - val_mean_absolute_percentage_error: 37.1187
# Epoch 14/100
# 1004/1004 [==============================] - 0s 152us/sample - loss: 0.0223 - mean_absolute_percentage_error: 495902.1562 - val_loss: 0.0249 - val_mean_absolute_percentage_error: 34.0195
# Epoch 15/100
# 1004/1004 [==============================] - 0s 148us/sample - loss: 0.0217 - mean_absolute_percentage_error: 334075.6875 - val_loss: 0.0233 - val_mean_absolute_percentage_error: 36.5707
# Epoch 16/100
# 1004/1004 [==============================] - 0s 144us/sample - loss: 0.0217 - mean_absolute_percentage_error: 352459.6562 - val_loss: 0.0234 - val_mean_absolute_percentage_error: 34.9979
# Epoch 17/100
# 1004/1004 [==============================] - 0s 152us/sample - loss: 0.0217 - mean_absolute_percentage_error: 351373.7500 - val_loss: 0.0233 - val_mean_absolute_percentage_error: 38.1242
# Epoch 18/100
# 1004/1004 [==============================] - 0s 151us/sample - loss: 0.0212 - mean_absolute_percentage_error: 367657.6875 - val_loss: 0.0243 - val_mean_absolute_percentage_error: 34.1255
# Epoch 19/100
# 1004/1004 [==============================] - 0s 149us/sample - loss: 0.0215 - mean_absolute_percentage_error: 346727.3125 - val_loss: 0.0237 - val_mean_absolute_percentage_error: 34.6649
# Epoch 20/100
# 1004/1004 [==============================] - 0s 150us/sample - loss: 0.0215 - mean_absolute_percentage_error: 379549.9375 - val_loss: 0.0227 - val_mean_absolute_percentage_error: 35.6111
# Epoch 21/100
# 1004/1004 [==============================] - 0s 159us/sample - loss: 0.0213 - mean_absolute_percentage_error: 370338.9375 - val_loss: 0.0230 - val_mean_absolute_percentage_error: 35.8591
# Epoch 22/100
# 1004/1004 [==============================] - 0s 158us/sample - loss: 0.0213 - mean_absolute_percentage_error: 344699.4062 - val_loss: 0.0227 - val_mean_absolute_percentage_error: 37.0709
# Epoch 23/100
# 1004/1004 [==============================] - 0s 151us/sample - loss: 0.0217 - mean_absolute_percentage_error: 380038.6875 - val_loss: 0.0235 - val_mean_absolute_percentage_error: 34.2200
# Epoch 24/100
# 1004/1004 [==============================] - 0s 152us/sample - loss: 0.0211 - mean_absolute_percentage_error: 373115.1250 - val_loss: 0.0239 - val_mean_absolute_percentage_error: 33.9757
# Epoch 25/100
# 1004/1004 [==============================] - 0s 151us/sample - loss: 0.0211 - mean_absolute_percentage_error: 376081.8125 - val_loss: 0.0222 - val_mean_absolute_percentage_error: 35.3153
# Epoch 26/100
# 1004/1004 [==============================] - 0s 146us/sample - loss: 0.0210 - mean_absolute_percentage_error: 366722.7812 - val_loss: 0.0225 - val_mean_absolute_percentage_error: 37.0645
# Epoch 27/100
# 1004/1004 [==============================] - 0s 153us/sample - loss: 0.0209 - mean_absolute_percentage_error: 371285.1250 - val_loss: 0.0218 - val_mean_absolute_percentage_error: 37.3005
# Epoch 28/100
# 1004/1004 [==============================] - 0s 147us/sample - loss: 0.0206 - mean_absolute_percentage_error: 359131.8750 - val_loss: 0.0219 - val_mean_absolute_percentage_error: 37.4302
# Epoch 29/100
# 1004/1004 [==============================] - 0s 144us/sample - loss: 0.0209 - mean_absolute_percentage_error: 372522.9688 - val_loss: 0.0232 - val_mean_absolute_percentage_error: 36.5970
# Epoch 30/100
# 1004/1004 [==============================] - 0s 150us/sample - loss: 0.0206 - mean_absolute_percentage_error: 391770.1875 - val_loss: 0.0220 - val_mean_absolute_percentage_error: 35.5143
# Epoch 31/100
# 1004/1004 [==============================] - 0s 155us/sample - loss: 0.0210 - mean_absolute_percentage_error: 328686.2812 - val_loss: 0.0226 - val_mean_absolute_percentage_error: 36.3275
# Epoch 32/100
# 1004/1004 [==============================] - 0s 146us/sample - loss: 0.0205 - mean_absolute_percentage_error: 378044.9688 - val_loss: 0.0222 - val_mean_absolute_percentage_error: 36.1927
# Epoch 33/100
# 1004/1004 [==============================] - 0s 143us/sample - loss: 0.0206 - mean_absolute_percentage_error: 381300.4688 - val_loss: 0.0232 - val_mean_absolute_percentage_error: 34.4981
# Epoch 34/100
# 1004/1004 [==============================] - 0s 156us/sample - loss: 0.0206 - mean_absolute_percentage_error: 397647.2188 - val_loss: 0.0228 - val_mean_absolute_percentage_error: 33.8865
# Epoch 35/100
# 1004/1004 [==============================] - 0s 148us/sample - loss: 0.0207 - mean_absolute_percentage_error: 391279.9688 - val_loss: 0.0231 - val_mean_absolute_percentage_error: 34.8992
# Epoch 36/100
# 1004/1004 [==============================] - 0s 146us/sample - loss: 0.0204 - mean_absolute_percentage_error: 348825.8438 - val_loss: 0.0222 - val_mean_absolute_percentage_error: 35.7138
# Epoch 37/100
# 1004/1004 [==============================] - 0s 146us/sample - loss: 0.0204 - mean_absolute_percentage_error: 362504.9062 - val_loss: 0.0246 - val_mean_absolute_percentage_error: 34.1527
# Epoch 38/100
# 1004/1004 [==============================] - 0s 149us/sample - loss: 0.0204 - mean_absolute_percentage_error: 393777.8125 - val_loss: 0.0219 - val_mean_absolute_percentage_error: 36.0562
# Epoch 39/100
# 1004/1004 [==============================] - 0s 323us/sample - loss: 0.0205 - mean_absolute_percentage_error: 395595.7188 - val_loss: 0.0224 - val_mean_absolute_percentage_error: 38.9427
# Epoch 40/100
# 1004/1004 [==============================] - 0s 188us/sample - loss: 0.0203 - mean_absolute_percentage_error: 360401.7188 - val_loss: 0.0215 - val_mean_absolute_percentage_error: 37.6870
# Epoch 41/100
# 1004/1004 [==============================] - 0s 191us/sample - loss: 0.0204 - mean_absolute_percentage_error: 386422.4062 - val_loss: 0.0222 - val_mean_absolute_percentage_error: 35.4480
# Epoch 42/100
# 1004/1004 [==============================] - 0s 162us/sample - loss: 0.0203 - mean_absolute_percentage_error: 384486.6875 - val_loss: 0.0221 - val_mean_absolute_percentage_error: 38.8454
# Epoch 43/100
# 1004/1004 [==============================] - 0s 183us/sample - loss: 0.0201 - mean_absolute_percentage_error: 338791.8125 - val_loss: 0.0220 - val_mean_absolute_percentage_error: 37.8706
# Epoch 44/100
# 1004/1004 [==============================] - 0s 166us/sample - loss: 0.0206 - mean_absolute_percentage_error: 346790.6562 - val_loss: 0.0220 - val_mean_absolute_percentage_error: 37.1939
# Epoch 45/100
# 1004/1004 [==============================] - 0s 170us/sample - loss: 0.0212 - mean_absolute_percentage_error: 364646.9375 - val_loss: 0.0225 - val_mean_absolute_percentage_error: 33.9524
# Epoch 46/100
# 1004/1004 [==============================] - 0s 204us/sample - loss: 0.0203 - mean_absolute_percentage_error: 380171.8438 - val_loss: 0.0221 - val_mean_absolute_percentage_error: 36.5506
# Epoch 47/100
# 1004/1004 [==============================] - 0s 186us/sample - loss: 0.0201 - mean_absolute_percentage_error: 365963.8125 - val_loss: 0.0228 - val_mean_absolute_percentage_error: 34.6069
# Epoch 48/100
# 1004/1004 [==============================] - 0s 193us/sample - loss: 0.0199 - mean_absolute_percentage_error: 421796.7188 - val_loss: 0.0231 - val_mean_absolute_percentage_error: 33.9726
# Epoch 49/100
# 1004/1004 [==============================] - 0s 168us/sample - loss: 0.0200 - mean_absolute_percentage_error: 371729.9688 - val_loss: 0.0220 - val_mean_absolute_percentage_error: 36.6703
# Epoch 50/100
# 1004/1004 [==============================] - 0s 192us/sample - loss: 0.0203 - mean_absolute_percentage_error: 358382.2500 - val_loss: 0.0221 - val_mean_absolute_percentage_error: 34.3003
# Epoch 51/100
# 1004/1004 [==============================] - 0s 192us/sample - loss: 0.0196 - mean_absolute_percentage_error: 380027.0000 - val_loss: 0.0221 - val_mean_absolute_percentage_error: 34.2447
# Epoch 52/100
# 1004/1004 [==============================] - 0s 177us/sample - loss: 0.0201 - mean_absolute_percentage_error: 355391.9688 - val_loss: 0.0233 - val_mean_absolute_percentage_error: 33.9335
# Epoch 53/100
# 1004/1004 [==============================] - 0s 162us/sample - loss: 0.0204 - mean_absolute_percentage_error: 366636.6562 - val_loss: 0.0222 - val_mean_absolute_percentage_error: 35.0784
# Epoch 54/100
# 1004/1004 [==============================] - 0s 167us/sample - loss: 0.0199 - mean_absolute_percentage_error: 321277.2500 - val_loss: 0.0242 - val_mean_absolute_percentage_error: 33.3395
# Epoch 55/100
# 1004/1004 [==============================] - 0s 158us/sample - loss: 0.0197 - mean_absolute_percentage_error: 368426.9688 - val_loss: 0.0228 - val_mean_absolute_percentage_error: 35.7084
# Epoch 56/100
# 1004/1004 [==============================] - 0s 161us/sample - loss: 0.0201 - mean_absolute_percentage_error: 388774.5938 - val_loss: 0.0224 - val_mean_absolute_percentage_error: 35.1955
# Epoch 57/100
# 1004/1004 [==============================] - 0s 154us/sample - loss: 0.0202 - mean_absolute_percentage_error: 358992.9688 - val_loss: 0.0225 - val_mean_absolute_percentage_error: 33.8786
# Epoch 58/100
# 1004/1004 [==============================] - 0s 147us/sample - loss: 0.0199 - mean_absolute_percentage_error: 373543.7500 - val_loss: 0.0238 - val_mean_absolute_percentage_error: 34.0612
# Epoch 59/100
# 1004/1004 [==============================] - 0s 154us/sample - loss: 0.0202 - mean_absolute_percentage_error: 373864.1875 - val_loss: 0.0226 - val_mean_absolute_percentage_error: 33.0555
# Epoch 60/100
# 1004/1004 [==============================] - 0s 151us/sample - loss: 0.0202 - mean_absolute_percentage_error: 402505.0938 - val_loss: 0.0221 - val_mean_absolute_percentage_error: 36.1156
# Epoch 61/100
# 1004/1004 [==============================] - 0s 152us/sample - loss: 0.0201 - mean_absolute_percentage_error: 406086.2188 - val_loss: 0.0244 - val_mean_absolute_percentage_error: 32.6039
# Epoch 62/100
# 1004/1004 [==============================] - 0s 147us/sample - loss: 0.0197 - mean_absolute_percentage_error: 354464.5000 - val_loss: 0.0241 - val_mean_absolute_percentage_error: 40.8569
# Epoch 63/100
# 1004/1004 [==============================] - 0s 158us/sample - loss: 0.0199 - mean_absolute_percentage_error: 376162.5000 - val_loss: 0.0223 - val_mean_absolute_percentage_error: 33.6700
# Epoch 64/100
# 1004/1004 [==============================] - 0s 154us/sample - loss: 0.0197 - mean_absolute_percentage_error: 385878.6250 - val_loss: 0.0238 - val_mean_absolute_percentage_error: 33.2061
# Epoch 65/100
# 1004/1004 [==============================] - 0s 154us/sample - loss: 0.0194 - mean_absolute_percentage_error: 376885.1562 - val_loss: 0.0224 - val_mean_absolute_percentage_error: 34.9751
# Epoch 66/100
# 1004/1004 [==============================] - 0s 156us/sample - loss: 0.0195 - mean_absolute_percentage_error: 332472.4062 - val_loss: 0.0214 - val_mean_absolute_percentage_error: 36.7583
# Epoch 67/100
# 1004/1004 [==============================] - 0s 176us/sample - loss: 0.0192 - mean_absolute_percentage_error: 411024.4062 - val_loss: 0.0213 - val_mean_absolute_percentage_error: 37.5964
# Epoch 68/100
# 1004/1004 [==============================] - 0s 160us/sample - loss: 0.0193 - mean_absolute_percentage_error: 367279.6875 - val_loss: 0.0231 - val_mean_absolute_percentage_error: 34.4879
# Epoch 69/100
# 1004/1004 [==============================] - 0s 184us/sample - loss: 0.0195 - mean_absolute_percentage_error: 362692.2500 - val_loss: 0.0221 - val_mean_absolute_percentage_error: 37.2420
# Epoch 70/100
# 1004/1004 [==============================] - 0s 214us/sample - loss: 0.0194 - mean_absolute_percentage_error: 384791.6562 - val_loss: 0.0229 - val_mean_absolute_percentage_error: 34.4073
# Epoch 71/100
# 1004/1004 [==============================] - 0s 210us/sample - loss: 0.0193 - mean_absolute_percentage_error: 339797.4688 - val_loss: 0.0222 - val_mean_absolute_percentage_error: 36.5806
# Epoch 72/100
# 1004/1004 [==============================] - 0s 210us/sample - loss: 0.0192 - mean_absolute_percentage_error: 398865.9375 - val_loss: 0.0214 - val_mean_absolute_percentage_error: 34.4160
# Epoch 73/100
# 1004/1004 [==============================] - 0s 213us/sample - loss: 0.0197 - mean_absolute_percentage_error: 361187.0312 - val_loss: 0.0215 - val_mean_absolute_percentage_error: 35.0867
# Epoch 74/100
# 1004/1004 [==============================] - 0s 194us/sample - loss: 0.0193 - mean_absolute_percentage_error: 388230.9375 - val_loss: 0.0236 - val_mean_absolute_percentage_error: 33.4500
# Epoch 75/100
# 1004/1004 [==============================] - 0s 218us/sample - loss: 0.0192 - mean_absolute_percentage_error: 378642.9688 - val_loss: 0.0218 - val_mean_absolute_percentage_error: 34.1106
# Epoch 76/100
# 1004/1004 [==============================] - 0s 172us/sample - loss: 0.0191 - mean_absolute_percentage_error: 386348.9688 - val_loss: 0.0260 - val_mean_absolute_percentage_error: 33.1826
# Epoch 77/100
# 1004/1004 [==============================] - 0s 187us/sample - loss: 0.0194 - mean_absolute_percentage_error: 354180.1562 - val_loss: 0.0216 - val_mean_absolute_percentage_error: 38.5093
# Epoch 78/100
# 1004/1004 [==============================] - 0s 170us/sample - loss: 0.0194 - mean_absolute_percentage_error: 389817.1875 - val_loss: 0.0216 - val_mean_absolute_percentage_error: 33.9778
# Epoch 79/100
# 1004/1004 [==============================] - 0s 167us/sample - loss: 0.0194 - mean_absolute_percentage_error: 391062.2812 - val_loss: 0.0212 - val_mean_absolute_percentage_error: 34.7197
# Epoch 80/100
# 1004/1004 [==============================] - 0s 204us/sample - loss: 0.0190 - mean_absolute_percentage_error: 354280.3438 - val_loss: 0.0217 - val_mean_absolute_percentage_error: 36.5227
# Epoch 81/100
# 1004/1004 [==============================] - 0s 176us/sample - loss: 0.0190 - mean_absolute_percentage_error: 379199.4062 - val_loss: 0.0223 - val_mean_absolute_percentage_error: 33.8803
# Epoch 82/100
# 1004/1004 [==============================] - 0s 193us/sample - loss: 0.0189 - mean_absolute_percentage_error: 372713.4375 - val_loss: 0.0223 - val_mean_absolute_percentage_error: 34.1199
# Epoch 83/100
# 1004/1004 [==============================] - 0s 163us/sample - loss: 0.0192 - mean_absolute_percentage_error: 354852.5000 - val_loss: 0.0210 - val_mean_absolute_percentage_error: 35.1099
# Epoch 84/100
# 1004/1004 [==============================] - 0s 155us/sample - loss: 0.0192 - mean_absolute_percentage_error: 335799.2500 - val_loss: 0.0211 - val_mean_absolute_percentage_error: 34.7699
# Epoch 85/100
# 1004/1004 [==============================] - 0s 183us/sample - loss: 0.0192 - mean_absolute_percentage_error: 375831.1250 - val_loss: 0.0214 - val_mean_absolute_percentage_error: 38.1602
# Epoch 86/100
# 1004/1004 [==============================] - 0s 169us/sample - loss: 0.0194 - mean_absolute_percentage_error: 370620.8750 - val_loss: 0.0239 - val_mean_absolute_percentage_error: 32.5616
# Epoch 87/100
# 1004/1004 [==============================] - 0s 162us/sample - loss: 0.0196 - mean_absolute_percentage_error: 353871.9062 - val_loss: 0.0224 - val_mean_absolute_percentage_error: 33.4899
# Epoch 88/100
# 1004/1004 [==============================] - 0s 155us/sample - loss: 0.0195 - mean_absolute_percentage_error: 388299.2812 - val_loss: 0.0225 - val_mean_absolute_percentage_error: 33.7682
# Epoch 89/100
# 1004/1004 [==============================] - 0s 154us/sample - loss: 0.0194 - mean_absolute_percentage_error: 372987.3125 - val_loss: 0.0224 - val_mean_absolute_percentage_error: 33.4635
# Epoch 90/100
# 1004/1004 [==============================] - 0s 149us/sample - loss: 0.0190 - mean_absolute_percentage_error: 350536.5938 - val_loss: 0.0213 - val_mean_absolute_percentage_error: 34.6415
# Epoch 91/100
# 1004/1004 [==============================] - 0s 147us/sample - loss: 0.0192 - mean_absolute_percentage_error: 374786.9375 - val_loss: 0.0232 - val_mean_absolute_percentage_error: 33.6311
# Epoch 92/100
# 1004/1004 [==============================] - 0s 154us/sample - loss: 0.0191 - mean_absolute_percentage_error: 387467.2188 - val_loss: 0.0216 - val_mean_absolute_percentage_error: 34.7383
# Epoch 93/100
# 1004/1004 [==============================] - 0s 152us/sample - loss: 0.0188 - mean_absolute_percentage_error: 374591.7812 - val_loss: 0.0218 - val_mean_absolute_percentage_error: 33.6757
# Epoch 94/100
# 1004/1004 [==============================] - 0s 155us/sample - loss: 0.0188 - mean_absolute_percentage_error: 359932.1562 - val_loss: 0.0216 - val_mean_absolute_percentage_error: 34.8382
# Epoch 95/100
# 1004/1004 [==============================] - 0s 149us/sample - loss: 0.0188 - mean_absolute_percentage_error: 373717.8125 - val_loss: 0.0212 - val_mean_absolute_percentage_error: 34.7034
# Epoch 96/100
# 1004/1004 [==============================] - 0s 153us/sample - loss: 0.0192 - mean_absolute_percentage_error: 377006.1250 - val_loss: 0.0224 - val_mean_absolute_percentage_error: 33.3421
# Epoch 97/100
# 1004/1004 [==============================] - 0s 201us/sample - loss: 0.0185 - mean_absolute_percentage_error: 350224.9688 - val_loss: 0.0221 - val_mean_absolute_percentage_error: 34.3990
# Epoch 98/100
# 1004/1004 [==============================] - 0s 167us/sample - loss: 0.0189 - mean_absolute_percentage_error: 398335.0938 - val_loss: 0.0218 - val_mean_absolute_percentage_error: 33.2582
# Epoch 99/100
# 1004/1004 [==============================] - 0s 159us/sample - loss: 0.0189 - mean_absolute_percentage_error: 381787.0312 - val_loss: 0.0219 - val_mean_absolute_percentage_error: 33.5523
# Epoch 100/100
# 1004/1004 [==============================] - 0s 154us/sample - loss: 0.0190 - mean_absolute_percentage_error: 393181.8750 - val_loss: 0.0225 - val_mean_absolute_percentage_error: 34.9347
# 419/419 - 0s - loss: 0.0234 - mean_absolute_percentage_error: 39.9891
# Test loss: 0.023407724772653318
# MAPE: 39.98913

# %%
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor

# %%
inputs = keras.Input(shape =(14,) )

dense = layers.Dense(64,activation ="tanh")
x = dense(inputs)

x = layers.Dense(64,activation="tanh")(x)

outputs = layers.Dense(1)(x)

model = keras.Model(inputs=inputs,outputs=outputs,name="test1")

# %%
def build_model(activation , optimizer):
    inputs = keras.Input(shape =(14,) )
    dense = layers.Dense(64,activation =activation)
    x = dense(inputs)

    x = layers.Dense(64,activation=activation)(x)

    outputs = layers.Dense(1)(x)

    model = keras.Model(inputs=inputs,outputs=outputs,name="test1")
    optimizer = optimizer
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['mean_absolute_error', 'mean_squared_error'])
    return model

# %%
#グリッドサーチ対象のハイパーパラメーターを準備
activation = ["relu", "tahn"]
optimizer = ["adam", "adagrad","sgd"]
nb_epoch = [10,50,100]
batch_size = [10,50,100]
 
#グリッドサーチ対象のハイパーパラメーターを辞書型にまとめる
param_grid = dict(activation=activation, optimizer=optimizer,nb_epoch=nb_epoch, batch_size=batch_size)
 
#モデルを作成
model = KerasRegressor(build_fn = build_model, verbose=0)
 
#グリッドサーチの実行
grid = GridSearchCV(estimator=model, param_grid=param_grid)
grid_result = grid.fit(zenbu_train[:,0:14], zenbu_train[:,14:])
# Out:
# C:\Users\meina\Anaconda3\envs\py3-TF2\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\meina\Anaconda3\envs\py3-TF2\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\meina\Anaconda3\envs\py3-TF2\lib\site-packages\tensorflow_core\python\keras\wrappers\scikit_learn.py", line 157, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-18-3ecdcf777f7b>", line 3, in build_model
#     dense = layers.Dense(64,activation =activation)
#   File "C:\Users\meina\Anaconda3\envs\py3-TF2\lib\site-packages\tensorflow_core\python\keras\layers\core.py", line 1082, in __init__
#     self.activation = activations.get(activation)
#   File "C:\Users\meina\Anaconda3\envs\py3-TF2\lib\site-packages\tensorflow_core\python\keras\activations.py", line 445, in get
#     return deserialize(identifier)
#   File "C:\Users\meina\Anaconda3\envs\py3-TF2\lib\site-packages\tensorflow_core\python\keras\activations.py", line 407, in deserialize
#     printable_module_name='activation function')
#   File "C:\Users\meina\Anaconda3\envs\py3-TF2\lib\site-packages\tensorflow_core\python\keras\utils\generic_utils.py", line 322, in deserialize_keras_object
#     raise ValueError('Unknown ' + printable_module_name + ':' + object_name)
# ValueError: Unknown activation function:tahn
#
#   FitFailedWarning)

# %%
print (grid_result.best_params_)
# Out:
# {'activation': 'relu', 'batch_size': 10, 'nb_epoch': 100, 'optimizer': 'adam'}

# %%
print(grid_result.best_score_)
# Out:
# -0.023931789220091825
