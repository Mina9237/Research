# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
#from sklearn.model_selection import train_test_split
import pandas as pd
import sys
import collections
import matplotlib.pyplot as plt
# data process
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
all_data= pd.read_excel("./20160809sakujo.xlsx")




#print(all_data.head())
#sys.exit()
#print(all_data_2.head())
#print(all_data.isnull().sum())
all_data_2 = all_data
#all_data_2 de,zyuuhukusurugyougaaru
#(all_data_2[all_data_2.duplicated()])

#sys.exit()
#print(all_data_2.isnull().sum())
#print(all_data_2.describe())
#sys.exit()
#print(len(all_data2))
time = []
time = all_data_2["Time"].unique()
kyoten = []
kyoten = all_data_2["name"].unique()

#band = []
list2 = []
list3 = []
list4 = []
pixel2 = []
CH2 = []
Cloud = []
terrian = []
CC = []
CS = []
for t in time:
    for n in kyoten:
        #band = all_data_2["band"][(all_data_2["Time"] == t) & (all_data_2["name"]== n)].values
        pixel2 = all_data_2["pixel"][(all_data_2["Time"] == t) & (all_data_2["name"] == n)].values
        CH2 = all_data_2["CH"][(all_data_2["Time"] == t) & (all_data_2["name"] == n)].values
        Cloud = all_data_2["cloud"][(all_data_2["Time"] == t) & (all_data_2["name"] == n)].values
        #terrian = all_data_2["terrian"][(all_data_2["Time"] == t) & (all_data_2["name"] == n)].values
        CC = all_data_2["cloudconfidence"][(all_data_2["Time"] == t) & (all_data_2["name"] == n)].values
        CS = all_data_2["cloudshade"][(all_data_2["Time"] == t) & (all_data_2["name"] == n)].values
        # print(CH1)
        if len(CH2) != 0:
            #list2 += [[n,t,pixel2, Cloud[0], terrian[0], CC[0], CS[0], CH2[0]]]
            list3 += [[pixel2, Cloud[0],CC[0], CS[0]]]
            list4 += [[CH2[0]]]

# print(list)

# array = np.array(list)
# rray
#array8 = np.array(list2)
#array8

""" 
with open("/home/meinai929/data_cleansed/mistake.txt","w") as f: 
    for i in range(0,1134): 
    #print(len(data_array[i][0])) 
        if len(array8[i][2]) != 11: 
            print(array8[i],file = f) 
 
"""
#ys.exit()
data_array = np.array(list3)
CH_array = np.array(list4)

#print(data_array.shape)
#print(CH_array.shape)
#sys.exit()
#data_array & CH_array numuber of rows are same (1134,1) (1134,5)
#print(data_array[0][0])
#print(len(data_array[0][0]))

#band no kazu ga, 10 to 22 no tokoro ga aru


#np.savetxt("/home/meinai929/data_cleansed/data_array_1205.txt",data_array,fmt = "%s")

#sys.exit()
def flatten(l):
    for el in l:
        if isinstance(el, collections.Iterable) and not isinstance(el, (str, bytes)):
            yield from flatten(el)
        else:
            yield el

list1 =[]
for x in data_array:
    list1 += flatten(x)

#print(len(list1))
#26415 1761*15= 26415ninaruhazu
#sys.exit()

def split_list(l, n):
    """ 
    リストをサブリストに分割する 
    :param l: リスト 
    :param n: サブリストの要素数 
    :return: 
    """
    for idx in range(0, len(l), n):
        yield l[idx:idx + n]

#print(list(split_list(list1, 14)))
inputs = np.array(list(split_list(list1, 14)))


scaler = preprocessing.MinMaxScaler()
#sc = StandardScaler()
#inputs_seikika = scaler.fit_transform(inputs)
#nputs_seikika_pixel = scaler.fit_transform(inputs[:,0:11])
#nputs_seikika_cloud = scaler.fit_transform(inputs[:,11:])
pixel_log = scaler.fit_transform(np.log(inputs[:,0:11]))
cloud = scaler.fit_transform(inputs[:,11:])
#print(inputs_seikika_pixel)
#print(inputs_seikika_cloud)

#nputs_seikika = np.concatenate((inputs_seikika_pixel,inputs_seikika_cloud),axis = 1)

input_log = np.concatenate((pixel_log,cloud),axis=1)
#print(input_log)

# %%
from sklearn.model_selection import train_test_split
#CH_seikika = scaler.fit_transform(CH_array)
CH_log = scaler.fit_transform(np.log(CH_array))
#print(CH_seikika)
#sys.exit()
#plt.plot(inputs_seikika,CH_array)
#plt.show()
#print(CH_seikika)
#sys.exit()

#print(inputs_seikika)

#sys.exit()
inputs_train, inputs_test = train_test_split(input_log, shuffle=False)
CH_train, CH_test = train_test_split(CH_log, shuffle=False)

#print(inputs_train.shape)
#sys.exit()
#print(inputs_train[0])
#print(CH_train.shape)
#print(inputs_train.shape)
#print(inputs.shape)
#print(CH_train.shape)
#sys.exit()
#print(inputs_train,CH_train)
#print(inputs_train.shape)
#print(inputs_train)

#sys.exit()
#input 15 * 1134
#model kouchiku
inputs = keras.Input(shape =(14,) )

dense = layers.Dense(64,activation ="tanh")
x = dense(inputs)

x = layers.Dense(64,activation="tanh")(x)

outputs = layers.Dense(1)(x)

model = keras.Model(inputs=inputs,outputs=outputs,name="test1")

model.compile(
    loss="mean_squared_error",
    optimizer="sgd",
    #metrics=["accuracy"],
    metrics=[tf.keras.metrics.MeanAbsolutePercentageError(
    name="mean_absolute_percentage_error", dtype=None
)]
)

history = model.fit(inputs_train, CH_train, batch_size=100, epochs=100, validation_split=0.2)

test_scores = model.evaluate(inputs_test, CH_test, verbose=2)
print("Test loss:", test_scores[0])
print("MAPE:", test_scores[1])
# Out:
# Train on 1004 samples, validate on 251 samples
# Epoch 1/100
# 1004/1004 [==============================] - 0s 424us/sample - loss: 0.0500 - mean_absolute_percentage_error: 433811.4375 - val_loss: 0.0506 - val_mean_absolute_percentage_error: 38.9136
# Epoch 2/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0320 - mean_absolute_percentage_error: 404855.2188 - val_loss: 0.0378 - val_mean_absolute_percentage_error: 34.2711
# Epoch 3/100
# 1004/1004 [==============================] - 0s 28us/sample - loss: 0.0276 - mean_absolute_percentage_error: 394227.3750 - val_loss: 0.0433 - val_mean_absolute_percentage_error: 34.7495
# Epoch 4/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0261 - mean_absolute_percentage_error: 346596.0625 - val_loss: 0.0361 - val_mean_absolute_percentage_error: 32.7333
# Epoch 5/100
# 1004/1004 [==============================] - 0s 30us/sample - loss: 0.0251 - mean_absolute_percentage_error: 362430.2812 - val_loss: 0.0263 - val_mean_absolute_percentage_error: 30.3318
# Epoch 6/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0248 - mean_absolute_percentage_error: 378125.1250 - val_loss: 0.0313 - val_mean_absolute_percentage_error: 31.0409
# Epoch 7/100
# 1004/1004 [==============================] - 0s 30us/sample - loss: 0.0241 - mean_absolute_percentage_error: 368661.2500 - val_loss: 0.0356 - val_mean_absolute_percentage_error: 32.3580
# Epoch 8/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0236 - mean_absolute_percentage_error: 366894.3750 - val_loss: 0.0391 - val_mean_absolute_percentage_error: 33.4511
# Epoch 9/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0235 - mean_absolute_percentage_error: 360456.9688 - val_loss: 0.0300 - val_mean_absolute_percentage_error: 31.3454
# Epoch 10/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0232 - mean_absolute_percentage_error: 380837.3125 - val_loss: 0.0390 - val_mean_absolute_percentage_error: 33.2376
# Epoch 11/100
# 1004/1004 [==============================] - 0s 30us/sample - loss: 0.0230 - mean_absolute_percentage_error: 371658.0312 - val_loss: 0.0331 - val_mean_absolute_percentage_error: 31.8110
# Epoch 12/100
# 1004/1004 [==============================] - 0s 30us/sample - loss: 0.0228 - mean_absolute_percentage_error: 375239.9688 - val_loss: 0.0295 - val_mean_absolute_percentage_error: 31.7782
# Epoch 13/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0230 - mean_absolute_percentage_error: 407780.8750 - val_loss: 0.0346 - val_mean_absolute_percentage_error: 32.3152
# Epoch 14/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0225 - mean_absolute_percentage_error: 389223.5938 - val_loss: 0.0345 - val_mean_absolute_percentage_error: 32.1120
# Epoch 15/100
# 1004/1004 [==============================] - 0s 32us/sample - loss: 0.0224 - mean_absolute_percentage_error: 384975.6562 - val_loss: 0.0301 - val_mean_absolute_percentage_error: 31.8562
# Epoch 16/100
# 1004/1004 [==============================] - 0s 30us/sample - loss: 0.0226 - mean_absolute_percentage_error: 409956.7500 - val_loss: 0.0331 - val_mean_absolute_percentage_error: 32.0100
# Epoch 17/100
# 1004/1004 [==============================] - 0s 37us/sample - loss: 0.0223 - mean_absolute_percentage_error: 381147.2500 - val_loss: 0.0409 - val_mean_absolute_percentage_error: 33.7718
# Epoch 18/100
# 1004/1004 [==============================] - 0s 26us/sample - loss: 0.0223 - mean_absolute_percentage_error: 365393.7500 - val_loss: 0.0397 - val_mean_absolute_percentage_error: 33.3656
# Epoch 19/100
# 1004/1004 [==============================] - 0s 28us/sample - loss: 0.0221 - mean_absolute_percentage_error: 365052.4062 - val_loss: 0.0314 - val_mean_absolute_percentage_error: 31.6176
# Epoch 20/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0222 - mean_absolute_percentage_error: 404923.8750 - val_loss: 0.0363 - val_mean_absolute_percentage_error: 32.7615
# Epoch 21/100
# 1004/1004 [==============================] - 0s 32us/sample - loss: 0.0221 - mean_absolute_percentage_error: 392529.4688 - val_loss: 0.0433 - val_mean_absolute_percentage_error: 34.4197
# Epoch 22/100
# 1004/1004 [==============================] - 0s 32us/sample - loss: 0.0221 - mean_absolute_percentage_error: 386804.4375 - val_loss: 0.0381 - val_mean_absolute_percentage_error: 33.3510
# Epoch 23/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0220 - mean_absolute_percentage_error: 386365.7812 - val_loss: 0.0389 - val_mean_absolute_percentage_error: 33.0571
# Epoch 24/100
# 1004/1004 [==============================] - 0s 31us/sample - loss: 0.0219 - mean_absolute_percentage_error: 369907.6250 - val_loss: 0.0387 - val_mean_absolute_percentage_error: 32.9589
# Epoch 25/100
# 1004/1004 [==============================] - 0s 32us/sample - loss: 0.0219 - mean_absolute_percentage_error: 367618.3438 - val_loss: 0.0393 - val_mean_absolute_percentage_error: 33.7392
# Epoch 26/100
# 1004/1004 [==============================] - 0s 34us/sample - loss: 0.0219 - mean_absolute_percentage_error: 396393.4688 - val_loss: 0.0383 - val_mean_absolute_percentage_error: 33.3651
# Epoch 27/100
# 1004/1004 [==============================] - 0s 32us/sample - loss: 0.0219 - mean_absolute_percentage_error: 387199.7812 - val_loss: 0.0384 - val_mean_absolute_percentage_error: 33.1911
# Epoch 28/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0218 - mean_absolute_percentage_error: 385991.8125 - val_loss: 0.0354 - val_mean_absolute_percentage_error: 32.1999
# Epoch 29/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0218 - mean_absolute_percentage_error: 381711.2812 - val_loss: 0.0372 - val_mean_absolute_percentage_error: 32.5987
# Epoch 30/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0217 - mean_absolute_percentage_error: 374414.7188 - val_loss: 0.0391 - val_mean_absolute_percentage_error: 33.1888
# Epoch 31/100
# 1004/1004 [==============================] - 0s 27us/sample - loss: 0.0217 - mean_absolute_percentage_error: 370668.3750 - val_loss: 0.0412 - val_mean_absolute_percentage_error: 33.4997
# Epoch 32/100
# 1004/1004 [==============================] - 0s 31us/sample - loss: 0.0218 - mean_absolute_percentage_error: 360065.2812 - val_loss: 0.0320 - val_mean_absolute_percentage_error: 32.8066
# Epoch 33/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0222 - mean_absolute_percentage_error: 440984.5312 - val_loss: 0.0397 - val_mean_absolute_percentage_error: 33.2947
# Epoch 34/100
# 1004/1004 [==============================] - 0s 31us/sample - loss: 0.0217 - mean_absolute_percentage_error: 377805.6875 - val_loss: 0.0412 - val_mean_absolute_percentage_error: 33.7734
# Epoch 35/100
# 1004/1004 [==============================] - 0s 35us/sample - loss: 0.0217 - mean_absolute_percentage_error: 385192.1875 - val_loss: 0.0358 - val_mean_absolute_percentage_error: 32.7146
# Epoch 36/100
# 1004/1004 [==============================] - 0s 30us/sample - loss: 0.0217 - mean_absolute_percentage_error: 375844.0312 - val_loss: 0.0387 - val_mean_absolute_percentage_error: 32.9422
# Epoch 37/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0216 - mean_absolute_percentage_error: 376750.8750 - val_loss: 0.0323 - val_mean_absolute_percentage_error: 31.7038
# Epoch 38/100
# 1004/1004 [==============================] - 0s 34us/sample - loss: 0.0218 - mean_absolute_percentage_error: 386682.6875 - val_loss: 0.0276 - val_mean_absolute_percentage_error: 31.6195
# Epoch 39/100
# 1004/1004 [==============================] - 0s 35us/sample - loss: 0.0222 - mean_absolute_percentage_error: 394080.4375 - val_loss: 0.0368 - val_mean_absolute_percentage_error: 32.3619
# Epoch 40/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0216 - mean_absolute_percentage_error: 364154.8125 - val_loss: 0.0319 - val_mean_absolute_percentage_error: 31.4390
# Epoch 41/100
# 1004/1004 [==============================] - 0s 36us/sample - loss: 0.0217 - mean_absolute_percentage_error: 367258.6250 - val_loss: 0.0362 - val_mean_absolute_percentage_error: 32.4448
# Epoch 42/100
# 1004/1004 [==============================] - 0s 34us/sample - loss: 0.0215 - mean_absolute_percentage_error: 374807.0312 - val_loss: 0.0440 - val_mean_absolute_percentage_error: 34.4950
# Epoch 43/100
# 1004/1004 [==============================] - 0s 31us/sample - loss: 0.0217 - mean_absolute_percentage_error: 355438.0000 - val_loss: 0.0330 - val_mean_absolute_percentage_error: 32.1772
# Epoch 44/100
# 1004/1004 [==============================] - 0s 31us/sample - loss: 0.0216 - mean_absolute_percentage_error: 374431.6562 - val_loss: 0.0345 - val_mean_absolute_percentage_error: 32.2044
# Epoch 45/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0215 - mean_absolute_percentage_error: 389522.6562 - val_loss: 0.0345 - val_mean_absolute_percentage_error: 32.2383
# Epoch 46/100
# 1004/1004 [==============================] - 0s 35us/sample - loss: 0.0215 - mean_absolute_percentage_error: 374511.7500 - val_loss: 0.0360 - val_mean_absolute_percentage_error: 32.1594
# Epoch 47/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0215 - mean_absolute_percentage_error: 369395.1250 - val_loss: 0.0353 - val_mean_absolute_percentage_error: 31.8080
# Epoch 48/100
# 1004/1004 [==============================] - 0s 36us/sample - loss: 0.0215 - mean_absolute_percentage_error: 362258.2500 - val_loss: 0.0327 - val_mean_absolute_percentage_error: 31.8436
# Epoch 49/100
# 1004/1004 [==============================] - 0s 35us/sample - loss: 0.0215 - mean_absolute_percentage_error: 376498.6562 - val_loss: 0.0292 - val_mean_absolute_percentage_error: 31.1427
# Epoch 50/100
# 1004/1004 [==============================] - 0s 34us/sample - loss: 0.0217 - mean_absolute_percentage_error: 359390.2812 - val_loss: 0.0353 - val_mean_absolute_percentage_error: 31.8151
# Epoch 51/100
# 1004/1004 [==============================] - 0s 37us/sample - loss: 0.0214 - mean_absolute_percentage_error: 352396.0312 - val_loss: 0.0330 - val_mean_absolute_percentage_error: 31.1325
# Epoch 52/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0215 - mean_absolute_percentage_error: 352649.1875 - val_loss: 0.0454 - val_mean_absolute_percentage_error: 34.5953
# Epoch 53/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0217 - mean_absolute_percentage_error: 354221.1875 - val_loss: 0.0379 - val_mean_absolute_percentage_error: 32.6314
# Epoch 54/100
# 1004/1004 [==============================] - 0s 35us/sample - loss: 0.0213 - mean_absolute_percentage_error: 363583.9375 - val_loss: 0.0315 - val_mean_absolute_percentage_error: 31.0136
# Epoch 55/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0215 - mean_absolute_percentage_error: 357199.5625 - val_loss: 0.0459 - val_mean_absolute_percentage_error: 34.7589
# Epoch 56/100
# 1004/1004 [==============================] - 0s 34us/sample - loss: 0.0216 - mean_absolute_percentage_error: 317429.3438 - val_loss: 0.0396 - val_mean_absolute_percentage_error: 32.7461
# Epoch 57/100
# 1004/1004 [==============================] - 0s 34us/sample - loss: 0.0214 - mean_absolute_percentage_error: 344720.6562 - val_loss: 0.0461 - val_mean_absolute_percentage_error: 34.8046
# Epoch 58/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0216 - mean_absolute_percentage_error: 307504.1250 - val_loss: 0.0397 - val_mean_absolute_percentage_error: 32.8683
# Epoch 59/100
# 1004/1004 [==============================] - 0s 35us/sample - loss: 0.0213 - mean_absolute_percentage_error: 344344.7812 - val_loss: 0.0371 - val_mean_absolute_percentage_error: 32.1187
# Epoch 60/100
# 1004/1004 [==============================] - 0s 35us/sample - loss: 0.0213 - mean_absolute_percentage_error: 354810.8125 - val_loss: 0.0338 - val_mean_absolute_percentage_error: 31.4536
# Epoch 61/100
# 1004/1004 [==============================] - 0s 35us/sample - loss: 0.0214 - mean_absolute_percentage_error: 363480.6562 - val_loss: 0.0399 - val_mean_absolute_percentage_error: 32.8337
# Epoch 62/100
# 1004/1004 [==============================] - 0s 35us/sample - loss: 0.0212 - mean_absolute_percentage_error: 339678.4062 - val_loss: 0.0390 - val_mean_absolute_percentage_error: 32.7967
# Epoch 63/100
# 1004/1004 [==============================] - 0s 32us/sample - loss: 0.0213 - mean_absolute_percentage_error: 354926.3438 - val_loss: 0.0314 - val_mean_absolute_percentage_error: 31.2748
# Epoch 64/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0214 - mean_absolute_percentage_error: 356759.4375 - val_loss: 0.0394 - val_mean_absolute_percentage_error: 32.5222
# Epoch 65/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0215 - mean_absolute_percentage_error: 320391.5312 - val_loss: 0.0313 - val_mean_absolute_percentage_error: 30.8541
# Epoch 66/100
# 1004/1004 [==============================] - 0s 37us/sample - loss: 0.0215 - mean_absolute_percentage_error: 349094.2188 - val_loss: 0.0318 - val_mean_absolute_percentage_error: 31.2485
# Epoch 67/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0214 - mean_absolute_percentage_error: 360863.7812 - val_loss: 0.0344 - val_mean_absolute_percentage_error: 31.5309
# Epoch 68/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0212 - mean_absolute_percentage_error: 349834.7188 - val_loss: 0.0305 - val_mean_absolute_percentage_error: 31.2591
# Epoch 69/100
# 1004/1004 [==============================] - 0s 43us/sample - loss: 0.0214 - mean_absolute_percentage_error: 355311.5938 - val_loss: 0.0329 - val_mean_absolute_percentage_error: 31.2181
# Epoch 70/100
# 1004/1004 [==============================] - 0s 39us/sample - loss: 0.0213 - mean_absolute_percentage_error: 359610.2500 - val_loss: 0.0319 - val_mean_absolute_percentage_error: 31.2726
# Epoch 71/100
# 1004/1004 [==============================] - 0s 36us/sample - loss: 0.0212 - mean_absolute_percentage_error: 353331.5625 - val_loss: 0.0381 - val_mean_absolute_percentage_error: 32.2963
# Epoch 72/100
# 1004/1004 [==============================] - 0s 35us/sample - loss: 0.0212 - mean_absolute_percentage_error: 344746.1250 - val_loss: 0.0365 - val_mean_absolute_percentage_error: 31.8918
# Epoch 73/100
# 1004/1004 [==============================] - 0s 34us/sample - loss: 0.0212 - mean_absolute_percentage_error: 353975.5312 - val_loss: 0.0309 - val_mean_absolute_percentage_error: 31.0798
# Epoch 74/100
# 1004/1004 [==============================] - 0s 40us/sample - loss: 0.0214 - mean_absolute_percentage_error: 377698.8125 - val_loss: 0.0384 - val_mean_absolute_percentage_error: 32.3868
# Epoch 75/100
# 1004/1004 [==============================] - 0s 37us/sample - loss: 0.0212 - mean_absolute_percentage_error: 344324.5938 - val_loss: 0.0358 - val_mean_absolute_percentage_error: 31.8419
# Epoch 76/100
# 1004/1004 [==============================] - 0s 35us/sample - loss: 0.0211 - mean_absolute_percentage_error: 349717.7188 - val_loss: 0.0377 - val_mean_absolute_percentage_error: 32.2586
# Epoch 77/100
# 1004/1004 [==============================] - 0s 35us/sample - loss: 0.0211 - mean_absolute_percentage_error: 347960.5312 - val_loss: 0.0359 - val_mean_absolute_percentage_error: 32.1040
# Epoch 78/100
# 1004/1004 [==============================] - 0s 34us/sample - loss: 0.0211 - mean_absolute_percentage_error: 351629.8438 - val_loss: 0.0347 - val_mean_absolute_percentage_error: 31.8603
# Epoch 79/100
# 1004/1004 [==============================] - 0s 37us/sample - loss: 0.0211 - mean_absolute_percentage_error: 355353.0312 - val_loss: 0.0391 - val_mean_absolute_percentage_error: 32.7102
# Epoch 80/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0211 - mean_absolute_percentage_error: 344275.4062 - val_loss: 0.0421 - val_mean_absolute_percentage_error: 33.3306
# Epoch 81/100
# 1004/1004 [==============================] - 0s 36us/sample - loss: 0.0213 - mean_absolute_percentage_error: 340753.0000 - val_loss: 0.0412 - val_mean_absolute_percentage_error: 33.1462
# Epoch 82/100
# 1004/1004 [==============================] - 0s 40us/sample - loss: 0.0212 - mean_absolute_percentage_error: 330789.3125 - val_loss: 0.0460 - val_mean_absolute_percentage_error: 34.6825
# Epoch 83/100
# 1004/1004 [==============================] - 0s 38us/sample - loss: 0.0215 - mean_absolute_percentage_error: 325198.7500 - val_loss: 0.0418 - val_mean_absolute_percentage_error: 33.3025
# Epoch 84/100
# 1004/1004 [==============================] - 0s 34us/sample - loss: 0.0211 - mean_absolute_percentage_error: 347085.9062 - val_loss: 0.0433 - val_mean_absolute_percentage_error: 33.8857
# Epoch 85/100
# 1004/1004 [==============================] - 0s 34us/sample - loss: 0.0212 - mean_absolute_percentage_error: 332640.9062 - val_loss: 0.0358 - val_mean_absolute_percentage_error: 31.9702
# Epoch 86/100
# 1004/1004 [==============================] - 0s 31us/sample - loss: 0.0211 - mean_absolute_percentage_error: 346715.5312 - val_loss: 0.0333 - val_mean_absolute_percentage_error: 31.4625
# Epoch 87/100
# 1004/1004 [==============================] - 0s 35us/sample - loss: 0.0211 - mean_absolute_percentage_error: 358350.5938 - val_loss: 0.0378 - val_mean_absolute_percentage_error: 32.3573
# Epoch 88/100
# 1004/1004 [==============================] - 0s 35us/sample - loss: 0.0211 - mean_absolute_percentage_error: 351458.5312 - val_loss: 0.0309 - val_mean_absolute_percentage_error: 31.2259
# Epoch 89/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0213 - mean_absolute_percentage_error: 358970.3125 - val_loss: 0.0383 - val_mean_absolute_percentage_error: 32.5461
# Epoch 90/100
# 1004/1004 [==============================] - 0s 34us/sample - loss: 0.0212 - mean_absolute_percentage_error: 346764.5938 - val_loss: 0.0431 - val_mean_absolute_percentage_error: 33.7298
# Epoch 91/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0212 - mean_absolute_percentage_error: 340556.1562 - val_loss: 0.0336 - val_mean_absolute_percentage_error: 31.4251
# Epoch 92/100
# 1004/1004 [==============================] - 0s 32us/sample - loss: 0.0211 - mean_absolute_percentage_error: 367904.3750 - val_loss: 0.0291 - val_mean_absolute_percentage_error: 30.9961
# Epoch 93/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0215 - mean_absolute_percentage_error: 381144.7188 - val_loss: 0.0334 - val_mean_absolute_percentage_error: 31.2135
# Epoch 94/100
# 1004/1004 [==============================] - 0s 35us/sample - loss: 0.0211 - mean_absolute_percentage_error: 361695.9688 - val_loss: 0.0344 - val_mean_absolute_percentage_error: 31.5133
# Epoch 95/100
# 1004/1004 [==============================] - 0s 34us/sample - loss: 0.0211 - mean_absolute_percentage_error: 353909.6875 - val_loss: 0.0445 - val_mean_absolute_percentage_error: 34.1632
# Epoch 96/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0212 - mean_absolute_percentage_error: 344822.0312 - val_loss: 0.0349 - val_mean_absolute_percentage_error: 31.4550
# Epoch 97/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0210 - mean_absolute_percentage_error: 346837.8125 - val_loss: 0.0347 - val_mean_absolute_percentage_error: 31.3834
# Epoch 98/100
# 1004/1004 [==============================] - 0s 35us/sample - loss: 0.0210 - mean_absolute_percentage_error: 340680.6562 - val_loss: 0.0286 - val_mean_absolute_percentage_error: 30.9084
# Epoch 99/100
# 1004/1004 [==============================] - 0s 29us/sample - loss: 0.0214 - mean_absolute_percentage_error: 386304.0938 - val_loss: 0.0375 - val_mean_absolute_percentage_error: 32.1727
# Epoch 100/100
# 1004/1004 [==============================] - 0s 33us/sample - loss: 0.0210 - mean_absolute_percentage_error: 342783.8750 - val_loss: 0.0398 - val_mean_absolute_percentage_error: 32.7801
# 419/419 - 0s - loss: 0.0260 - mean_absolute_percentage_error: 30.0211
# Test loss: 0.025988514555133613
# MAPE: 30.021109
